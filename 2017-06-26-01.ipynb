# %% [markdown]
# ## RFデータ読み込みテスト
#
# 中島君にもらったRFデータを色々扱ってみる

# %%
import numpy as np
import scipy.io as sio

# %% [markdown]
# Verasonicsが出力するmatファイルを読み込み

# %%
mat_path= "/mnt/recordings/ExperimentData/20160511/GraphiteGel_Rcvdata.mat"

# %%
dat_out = sio.loadmat(mat_path)
type(dat_out)
# Out:
# dict

# %% [markdown]
# 構造体がDictionaryで保存されているようだ。
#
# RFデータの実体はこいつ。

# %%
dat = dat_out['RcvData'][0][0]
dat.shape
# Out:
# (4096, 128, 64)

# %% [markdown]
# 可視化してみる

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pos_s = 32 #送信チャネル
pos_r = 32 #受信チャネル

# %% [markdown]
# ### 可視化

# %%
plt.plot(dat[:,pos_r, pos_s])

# %%
plt.imshow(dat[:400,:,pos_s], cmap='jet')
plt.colorbar()
