# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
def phase_add(a, b):
    a_ = np.cos(a) + np.sin(a)*1j
    b_ = np.cos(b) + np.sin(b)*1j
    return np.angle(a_*b_)

def phase_statics(X):
    a = 0
    for x in X: a += ( np.cos(x) + np.sin(x)*1j)
    a /= len(X)
    return np.angle(a), 1-np.abs(a)

def getAngleDensityMap(hist_phase, size = 512):
    img = np.zeros([size, size])
    center = [size / 2, size/2]
    print hist_phase
    for i in range(size): # y 
        for j in range(size): # x
            pos = ( j - center[1] ) + 1j*( i - center[0] )
            if np.abs(pos) < size / 2:
                img[i,j] = hist_phase[int( - ( np.angle( pos ) + np.pi ) / (0.1*np.pi) )]
    return img

# %%
data_dir = "/Volumes/HD-PLFU3/AnalysisResult/"
df_path = "/Users/tomii/tmp/AnalysisResult/pv_stim_pandas.csv"
winrad = 4

# %%
df = pd.read_csv(df_path)
df["stim_phase"] = np.zeros(len(df))
for i in range(len(df)):
    s = df.loc[i,:]    
    sess_dir = data_dir+"{0}/C001H001S{1:0>4}/".format(s.sample, s.session)
    print i, sess_dir
    
    pmap_data = np.load(sess_dir+'/pmap.npy')
    phases = pmap_data[s.frame_start, s.stim_x - winrad:s.stim_x+winrad, s.stim_y - winrad:s.stim_y+winrad]
    phases = phases.flatten()
    s.stim_phase, _ = phase_statics(phases)
    df.loc[i,:] = s
df.to_csv(df_path, index=False)
# Out:
# 0 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0008/
# 1 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0014/
# 2 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0015/
# 3 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0017/
# 4 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0034/
# 5 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0035/
# 6 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0036/
# 7 /Volumes/HD-PLFU3/AnalysisResult/20140911-2/C001H001S0038/
# 8 /Volumes/HD-PLFU3/AnalysisResult/20160907-3/C001H001S0006/
# 9 /Volumes/HD-PLFU3/AnalysisResult/20160907-3/C001H001S0010/
# 10 /Volumes/HD-PLFU3/AnalysisResult/20160907-3/C001H001S0011/
# 11 /Volumes/HD-PLFU3/AnalysisResult/20160907-3/C001H001S0017/
# 12 /Volumes/HD-PLFU3/AnalysisResult/20160907-3/C001H001S0022/
# 13 /Volumes/HD-PLFU3/AnalysisResult/20161019-1/C001H001S0018/
# 14 /Volumes/HD-PLFU3/AnalysisResult/20161019-1/C001H001S0019/
# 15 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0006/
# 16 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0007/
# 17 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0008/
# 18 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0009/
# 19 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0010/
# 20 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0011/
# 21 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0012/
# 22 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0013/
# 23 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0014/
# 24 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0015/
# 25 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0016/
# 26 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0017/
# 27 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0018/
# 28 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0019/
# 29 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0020/
# 30 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0021/
# 31 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0022/
# 32 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0023/
# 33 /Volumes/HD-PLFU3/AnalysisResult/20161019-2/C001H001S0024/
# 34 /Volumes/HD-PLFU3/AnalysisResult/20161019-3/C001H001S0024/
# 35 /Volumes/HD-PLFU3/AnalysisResult/20161019-3/C001H001S0025/
# 36 /Volumes/HD-PLFU3/AnalysisResult/20161021-1/C001H001S0009/
# 37 /Volumes/HD-PLFU3/AnalysisResult/20161021-1/C001H001S0010/
# 38 /Volumes/HD-PLFU3/AnalysisResult/20161021-1/C001H001S0011/
# 39 /Volumes/HD-PLFU3/AnalysisResult/20161021-1/C001H001S0012/
# 40 /Volumes/HD-PLFU3/AnalysisResult/20161021-1/C001H001S0013/
# 41 /Volumes/HD-PLFU3/AnalysisResult/20161021-1/C001H001S0014/
# 42 /Volumes/HD-PLFU3/AnalysisResult/20161021-1/C001H001S0016/
# 43 /Volumes/HD-PLFU3/AnalysisResult/20161021-2/C001H001S0010/
# 44 /Volumes/HD-PLFU3/AnalysisResult/20161021-2/C001H001S0011/
# 45 /Volumes/HD-PLFU3/AnalysisResult/20161021-2/C001H001S0012/
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:9: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df = pd.read_csv(df_path)
df
# Out:
#         sample  session  frame_start  frame_end  roi_top  roi_bottom  \
# 0   20140911-2        8          322        342        0         128
# 1   20140911-2       14          306        328       30         128
# 2   20140911-2       15          282        312        0         128
# 3   20140911-2       17          282        312        0         128
# 4   20140911-2       34          302        315       70         128
# 5   20140911-2       35          302        337        0         128
# 6   20140911-2       36          282        312        0         128
# 7   20140911-2       38          302        332        0         128
# 8   20160907-3        6          300        313       69         128
# 9   20160907-3       10          360        376        0         128
# 10  20160907-3       11          400        401        0         128
# 11  20160907-3       17          360        363        0         128
# 12  20160907-3       22          329        361       65         128
# 13  20161019-1       18          370        406       83         128
# 14  20161019-1       19          370        406       50         128
# 15  20161019-2        6          170        206        0         128
# 16  20161019-2        7          160        190        0         128
# 17  20161019-2        8          140        166        0         128
# 18  20161019-2        9          190        215        0         128
# 19  20161019-2       10          150        176        0         128
# 20  20161019-2       11          250        286        0         128
# 21  20161019-2       12          130        166        0         128
# 22  20161019-2       13          140        166        0         128
# 23  20161019-2       14          150        176        0         128
# 24  20161019-2       15          160        186        0         128
# 25  20161019-2       16          170        196        0         128
# 26  20161019-2       17          180        206        0         128
# 27  20161019-2       18          190        216        0         128
# 28  20161019-2       19          200        226        0         128
# 29  20161019-2       20          210        236        0         128
# 30  20161019-2       21          230        256        0         128
# 31  20161019-2       22          250        276        0         128
# 32  20161019-2       23          270        296        0         128
# 33  20161019-2       24          290        326        0         128
# 34  20161019-3       24          260        286        0         128
# 35  20161019-3       25          255        287        0         128
# 36  20161021-1        9          175        205       80         128
# 37  20161021-1       10          175        211        0         128
# 38  20161021-1       11          175        211        0         128
# 39  20161021-1       12          185        221       82         128
# 40  20161021-1       13          172        211        0         128
# 41  20161021-1       14          185        221       80         128
# 42  20161021-1       16          195        241       90         128
# 43  20161021-2       10          190        216        0         128
# 44  20161021-2       11          200        210        0         128
# 45  20161021-2       12          210        217        0         128
#
#     roi_left  roi_right  stim_x  stim_y  pre_x  pre_y  pst_x  pst_y  \
# 0         60        128      78      60     75     65     68     60
# 1          0        128      78      60     82     51     74     35
# 2          0        128      78      60     83     74     84     67
# 3          0        128      78      60     87     68     84     55
# 4          0        128      78      60     68     75     69     73
# 5          0        128      78      60     72     74     53     40
# 6          0        128      78      60     85     74     87     61
# 7          0        128      78      60     75     47     71     32
# 8          0        128      86      68    108     83    106     69
# 9          0         80      86      68     60     69     71     91
# 10         0        128      86      68    104     82    101     80
# 11         0         69      86      68     57     65     66     68
# 12         0        128      86      68     83     65    108     89
# 13         0        128      83      75     85     93     88     89
# 14         0        128      83      75     90     82     79     61
# 15         0        128      62      54     41     72     43     34
# 16         0        128      52      66     40     89     51     64
# 17         0        128      52      66     38     86     57     70
# 18         0        128      52      66     42     70     44     35
# 19         0        128      52      66     40     89     53     69
# 20         0        128      52      66     48     78     50     82
# 21         0        128      52      66     35     89     42     86
# 22         0        128      52      66     39     87     57     73
# 23         0        128      52      66     41     88     58     68
# 24         0        128      52      66     55     92     70     65
# 25         0        128      52      66     57     93     69     61
# 26         0        128      52      66     57     90     57     70
# 27         0        128      52      66     56     88     58     81
# 28         0        128      52      66     57     83     59     80
# 29         0        128      52      66     57     76     61     78
# 30         0        128      52      66     60     83     65     89
# 31         0        128      52      66     62     86     66     92
# 32         0        128      52      66     70     93     71     91
# 33         0        128      52      66     68     93     73     78
# 34        32        128      60      75     56     59     41     66
# 35        44        128      60      75     60     60     45     81
# 36         0        128      81      68     55     80     76     87
# 37         0        128      75      51     53     79     75     94
# 38         0        128      77      59     53     80     76     94
# 39         0        128      77      59     56     83     77     95
# 40        49         79      77      65     49     78     78     87
# 41         0        128      77      65     56     83     76     86
# 42         0        128      77      65     74     94     76     91
# 43        50        128      66      50     52     40     50     49
# 44        40        128      66      50     51     53     47     55
# 45         0        128      66      50     48     57     35     48
#
#     core_id_min  core_id_max  fb_angle  stim_phase
# 0             6            6  1.049658    1.235260
# 1            14           14  1.049658    0.633302
# 2             2            2  1.049658    0.782603
# 3             6            6  1.049658   -0.429301
# 4             7            7  1.049658    0.980198
# 5            12           12  1.049658    1.085959
# 6             5            5  1.049658   -0.466451
# 7            13           13  1.049658    0.419959
# 8             9            9  1.555173   -1.004775
# 9             5           10  1.555173    2.607067
# 10           10           10  1.555173   -2.480862
# 11            4            4  1.555173   -2.844697
# 12            3            3  1.555173    1.179007
# 13           16           16  0.960070   -2.713373
# 14           16           16  0.960070   -1.713514
# 15            8            8  1.570796   -1.965940
# 16            3            3  1.570796    1.422224
# 17            3            3  1.570796    0.304898
# 18           22           22  1.570796   -2.932302
# 19            5            5  1.570796    0.806643
# 20           24           24  1.570796    1.190270
# 21            7            7  1.570796    0.375236
# 22            7            7  1.570796    0.316385
# 23           13           13  1.570796    0.391686
# 24            5            5  1.570796    2.071929
# 25           14           14  1.570796    2.353750
# 26            4            4  1.570796    2.978063
# 27           10           10  1.570796   -2.805384
# 28            2            2  1.570796   -2.425574
# 29           15           15  1.570796   -1.662145
# 30            3            3  1.570796   -1.008636
# 31            7            7  1.570796   -0.194890
# 32            9            9  1.570796    0.566257
# 33            5            5  1.570796    1.062984
# 34           13           13  1.015041   -1.564731
# 35           14           14  1.015041   -2.041896
# 36            6            6  1.237212    2.081165
# 37            6            6  1.237212    1.398311
# 38           12           12  1.237212    1.617803
# 39            7            7  1.237212    1.804173
# 40            4            4  1.237212    1.712881
# 41            7            7  1.237212    1.907694
# 42           12           12  1.237212    2.178144
# 43            8            8  1.341269   -0.127977
# 44           12           12  1.341269   -0.078446
# 45           11           11  1.341269    0.148317

# %%
data = np.zeros([len(df), 4])
for i in range(len(df)):
    s = df.loc[i,:]    
    sess_dir = data_dir+"{0}/C001H001S{1:0>4}/".format(s.sample, s.session)
    #print i, sess_dir
    
    vec_pre = (s.stim_x - s.pre_x) + 1j*(s.stim_y - s.pre_y)
    shift = np.abs(((s.pst_x - s.pre_x) + 1j*(s.pst_y - s.pre_y)))
    
    d = np.array([s.stim_phase, np.abs(vec_pre), np.angle(vec_pre) - s.fb_angle, shift])
    data[i,:] = d
    print i, s.sample, s.session, d
# Out:
# 0 20140911-2 8 [ 1.23525972  5.83095189 -2.08003501  8.60232527]
# 1 20140911-2 14 [  0.63330154   9.8488578    0.93936247  17.88854382]
# 2 20140911-2 15 [  0.78260306  14.86606875  -2.96347845   7.07106781]
# 3 20140911-2 17 [ -0.42930068  12.04159458  -3.4646085   13.34166406]
# 4 20140911-2 34 [  0.98019815  18.02775638  -2.03245191   2.23606798]
# 5 20140911-2 35 [  1.08595941  15.23154621  -2.21556272  38.94868419]
# 6 20140911-2 36 [ -0.46645058  15.65247584  -3.08410212  13.15294644]
# 7 20140911-2 38 [  0.41995919  13.34166406   0.2943393   15.5241747 ]
# 8 20160907-3 6 [ -1.00477474  26.62705391  -4.09834636  14.14213562]
# 9 20160907-3 10 [  2.60706737  26.01922366  -1.59361519  24.59674775]
# 10 20160907-3 11 [ -2.48086182  22.8035085   -4.03572208   3.60555128]
# 11 20160907-3 17 [ -2.84469657  29.15475947  -1.45209099   9.48683298]
# 12 20160907-3 22 [  1.17900728   4.24264069  -0.76977443  34.6554469 ]
# 13 20161019-1 18 [ -2.71337265  18.11077028  -2.64152391   5.        ]
# 14 20161019-1 19 [ -1.71351379   9.89949494  -3.31626485  23.70653918]
# 15 20161019-2 6 [ -1.96593969  27.65863337  -2.2794226   38.05259518]
# 16 20161019-2 7 [  1.42222355  25.94224354  -2.66070537  27.31300057]
# 17 20161019-2 8 [  0.30489778  24.41311123  -2.53086669  24.8394847 ]
# 18 20161019-2 9 [ -2.93230223  10.77032961  -1.9513027   35.05709629]
# 19 20161019-2 10 [  0.80664284  25.94224354  -2.66070537  23.85372088]
# 20 20161019-2 11 [  1.19027011  12.64911064  -2.8198421    4.47213595]
# 21 20161019-2 12 [  0.37523625  28.60069929  -2.50508444   7.61577311]
# 22 20161019-2 13 [  0.3163855   24.69817807  -2.58728516  22.8035085 ]
# 23 20161019-2 14 [  0.39168574  24.59674775  -2.67794504  26.2488095 ]
# 24 20161019-2 15 [  2.07192915  26.17250466  -3.25646926  30.88689042]
# 25 20161019-2 16 [  2.35374954  27.45906044  -3.32470347  34.17601498]
# 26 20161019-2 17 [  2.97806321  24.51530134  -3.34698804  20.        ]
# 27 20161019-2 18 [ -2.80538421  22.36067977  -3.32144615   7.28010989]
# 28 20161019-2 19 [ -2.42557414  17.72004515  -3.4276441    3.60555128]
# 29 20161019-2 20 [ -1.66214547  11.18033989  -3.60524026   4.47213595]
# 30 20161019-2 21 [ -1.00863603  18.78829423  -3.58143524   7.81024968]
# 31 20161019-2 22 [ -0.19489023  22.36067977  -3.60524026   7.21110255]
# 32 20161019-2 23 [  0.56625714  32.44996148  -3.72959526   2.23606798]
# 33 20161019-2 24 [  1.06298427  31.38470965  -3.67654773  15.8113883 ]
# 34 20161019-3 24 [ -1.56473108  16.4924225    0.31077706  16.55294536]
# 35 20161019-3 25 [ -2.04189594  15.           0.55575572  25.8069758 ]
# 36 20161021-1 9 [  2.08116549  28.63564213  -1.66961978  22.13594362]
# 37 20161021-1 10 [  1.39831119  35.60898763  -2.14203909  26.62705391]
# 38 20161021-1 11 [  1.61780287  31.89043744  -1.956042    26.92582404]
# 39 20161021-1 12 [  1.80417312  31.89043744  -2.08917833  24.18677324]
# 40 20161021-1 13 [  1.7128814   30.87069808  -1.67188222  30.3644529 ]
# 41 20161021-1 14 [  1.90769356  27.65863337  -1.94583828  20.22374842]
# 42 20161021-1 16 [  2.17814431  29.15475947  -2.70492672   3.60555128]
# 43 20161021-2 10 [ -0.12797664  17.20465053  -0.72101949   9.21954446]
# 44 20161021-2 11 [ -0.07844631  15.29705854  -1.53866453   4.47213595]
# 45 20161021-2 12 [  0.14831675  19.31320792  -1.71216026  15.8113883 ]

# %%
#thre = np.max(data[:,2])*0.5
thre = np.mean(data[:,2])

x =  np.cos(data[:,0])
y = np.sin(data[:,0])
x *= np.absolute(np.cos(data[:,2]))
y *= np.absolute(np.cos(data[:,2]))

#rgb = (np.c_[data[:,2], data[:,2], data[:,2]] > thre)*1.0
rgb = np.c_[data[:,3], data[:,3], data[:,3]] / np.max(data[:,3])
#rgb[:,1] = 0.0
#rgb[:,2] = 1-rgb[:,0]

fig, ax = plt.subplots()
ax.scatter(x, y, s=100, facecolors=rgb)
plt.xlim([-1.5,1.5])
plt.ylim([-1.5,1.5])
plt.show()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
#thre = np.max(data[:,2])*0.5
thre = np.mean(data[:,2])

x =  np.cos(data[:,0])
y = np.sin(data[:,0])
x *= data[:,1]
y *= data[:,1]
#x /= np.max(data[:,1])
#y /= np.max(data[:,1])

#rgb = (np.c_[data[:,2], data[:,2], data[:,2]] > thre)*1.0
rgb = np.c_[data[:,3], data[:,3], data[:,3]] / np.max(data[:,3])
#rgb[:,1] = 0.0
#rgb[:,2] = 1-rgb[:,0]

fig, ax = plt.subplots()
ax.scatter(x, y, s=100, facecolors=rgb)
plt.xlim([-40,40])
plt.ylim([-40,40])
plt.show()

print np.mean(data[:,1])
# Out:
# 21.3125690317

# %%
np.cos(2.0)
# Out:
# -0.41614683654714241

# %%
np.max(data[:,2])
# Out:
# 38.948684188300895

# %%
print df.loc[list(np.where(data[:,0]   <  -0.5*np.pi )[0]), ["sample", "session", "frame_start"]]
print data[np.where(data[:,0]   <  -0.5*np.pi ), :]
# Out:
#         sample  session  frame_start
# 10  20160907-3       11          400
# 11  20160907-3       17          360
# 13  20161019-1       18          370
# 14  20161019-1       19          370
# 15  20161019-2        6          170
# 18  20161019-2        9          190
# 27  20161019-2       18          190
# 28  20161019-2       19          200
# 29  20161019-2       20          210
# 35  20161019-3       25          255
# [[[ -2.48086182  -4.03572208   3.60555128]
#   [ -2.84469657  -1.45209099   9.48683298]
#   [ -2.71337265  -2.64152391   5.        ]
#   [ -1.71351379  -3.31626485  23.70653918]
#   [ -1.96593969  -2.2794226   38.05259518]
#   [ -2.93230223  -1.9513027   35.05709629]
#   [ -2.80538421  -3.32144615   7.28010989]
#   [ -2.42557414  -3.4276441    3.60555128]
#   [ -1.66214547  -3.60524026   4.47213595]
#   [ -2.04189594   0.55575572  25.8069758 ]]]
